# %%
# coding: utf-8

"""
Crea una tabla con todos los csvs que se encuentran en ./accidents, selecciona 
solo las del estado y las caracteristicas indicadas en las variables 'estado' y 'dtypes'. 
Elimina aquellas que no tienen la posicion en la que ocurre la tormenta y pone las fechas en un formato adecuado. 
Finalmente vuelva el resultado en un archivo .csv
"""

import pandas as pd
import numpy as np
from functools import partial
from os import listdir

# %%
''' seleccionamos los accidentes del estado de indiana'''
estado = 'INDIANA'
accidents_csv = []
for csv in listdir('../Data/Iniciales/accidents/'):
    df = pd.read_csv('../Data/Iniciales/accidents/' + csv)
    df.set_index = "INDEX"
    accidents_csv.append(df)

accidents = pd.concat(accidents_csv)
                          
accidents = accidents[accidents['STATE'] == 1]

''' Eliminamos las columnas que no sirven'''

useless_data = ['ALIGNMNT', 'ARR_HOUR', 'ARR_MIN', 'CF1', 'CF2', 'CF3',
                'CITY', 'COUNTY', 'C_M_ZONE', 'DAY_WEEK', 'DRUNK_DR', 'FUNC_SYS',
                'HARM_EV', 'HIT_RUN', 'HOSP_HR', 'HOSP_MN', 'LGT_COND', 'MAN_COLL',
                'MILEPT', 'NHS', 'NOT_HOUR', 'NOT_MIN', 'NO_LANES', 'PAVE_TYP', 'PEDS',
                'PERMVIT', 'PERNOTMVIT', 'PERSONS', 'PROFILE', 'PVH_INVL', 'RAIL', 'RD_OWNER',
                'RELJCT1', 'RELJCT2', 'REL_JUNC', 'REL_ROAD', 'ROAD_FNC', 'ROUTE', 'RUR_URB',
                'SCH_BUS', 'SP_JUR', 'SP_LIMIT', 'ST_CASE', 'SUR_COND', 'TRAF_FLO', 'TRA_CONT',
                'TWAY_ID', 'TWAY_ID2', 'TYP_INT', 'T_CONT_F', 'VE_FORMS', 'VE_TOTAL', 'WEATHER',
                'WEATHER1', 'WEATHER2', 'WRK_ZONE']

accidents = accidents.drop(useless_data, axis=1)
accidents
# Out:
#       DAY  FATALS  HOUR   LATITUDE   LONGITUD  MINUTE  MONTH  STATE    YEAR
# 0     1.0     1.0   7.0  32.992778 -86.714469    30.0    1.0    1.0  2003.0
# 1     1.0     1.0  15.0  34.720764 -85.937033    50.0    1.0    1.0  2003.0
# 2     5.0     1.0  12.0  32.561533 -85.963558    19.0    1.0    1.0  2003.0
# 3     4.0     1.0   7.0  33.184503 -85.360019    50.0    1.0    1.0  2003.0
# 4     1.0     1.0  19.0  31.638442 -86.787378    30.0    1.0    1.0  2003.0
# 5    11.0     1.0  16.0  32.249086 -86.093311    20.0    1.0    1.0  2003.0
# 6     4.0     2.0  18.0  34.224758 -86.829319     0.0    1.0    1.0  2003.0
# 7    12.0     1.0   7.0  31.149983 -85.872903     5.0    1.0    1.0  2003.0
# 8     8.0     1.0   9.0  32.983581 -87.793661     0.0    1.0    1.0  2003.0
# 9     9.0     1.0  14.0  32.702097 -88.141697    43.0    1.0    1.0  2003.0
# 10   11.0     1.0   6.0  33.679650 -85.698081    50.0    1.0    1.0  2003.0
# 11   13.0     2.0   3.0  33.582508 -87.898136     0.0    1.0    1.0  2003.0
# 12    4.0     1.0  19.0  33.748764 -86.858731    20.0    1.0    1.0  2003.0
# 13    5.0     3.0  17.0  32.139892 -86.443078    20.0    1.0    1.0  2003.0
# 14   15.0     1.0   3.0  30.450675 -88.168225     0.0    1.0    1.0  2003.0
# 15   18.0     1.0   1.0  30.707006 -88.079742    50.0    1.0    1.0  2003.0
# 16   12.0     2.0   4.0  30.655381 -87.914006    30.0    1.0    1.0  2003.0
# 17    8.0     1.0  20.0  30.520989 -88.269031    40.0    1.0    1.0  2003.0
# 18   10.0     1.0  23.0  30.761433 -88.224692    30.0    1.0    1.0  2003.0
# 19   23.0     1.0  22.0  31.019447 -86.006197    45.0    1.0    1.0  2003.0
