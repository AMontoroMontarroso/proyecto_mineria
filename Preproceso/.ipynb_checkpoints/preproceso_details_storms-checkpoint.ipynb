# %%
import pandas as pd

# %%
details_df = pd.read_csv('../Data/Seleccion/details.csv')

# %%
details_df = details_df.set_index('EVENT_ID')

# %%
details_df
# Out:
#           EPISODE_ID         EVENT_TYPE     BEGIN_DATE_TIME  \
# EVENT_ID
# 307217       50714.0          Lightning  11-MAY-11 17:38:00
# 324730       54144.0               Hail  20-JUN-11 12:18:00
# 324732       54144.0  Thunderstorm Wind  20-JUN-11 07:46:00
# 324733       54144.0  Thunderstorm Wind  20-JUN-11 07:46:00
# 324735       54144.0  Thunderstorm Wind  20-JUN-11 07:33:00
# 324736       54144.0  Thunderstorm Wind  20-JUN-11 07:36:00
# 292417       49777.0              Flood  24-APR-11 17:00:00
# 296542       50351.0        Flash Flood  23-APR-11 14:45:00
# 316044       52854.0              Flood  27-JUN-11 10:00:00
# 316037       52854.0              Flood  27-JUN-11 09:00:00
# 316052       52854.0              Flood  25-JUN-11 23:59:00
# 316055       52854.0              Flood  25-JUN-11 11:15:00
# 299173       50712.0               Hail  07-MAY-11 15:55:00
# 299176       50712.0               Hail  07-MAY-11 16:15:00
# 299233       50714.0               Hail  11-MAY-11 17:30:00
# 299240       50714.0               Hail  11-MAY-11 17:41:00
# 297533       50498.0        Strong Wind  03-APR-11 09:00:00
# 297534       50498.0        Strong Wind  03-APR-11 09:00:00
# 297535       50498.0        Strong Wind  03-APR-11 09:00:00
# 297536       50498.0        Strong Wind  03-APR-11 09:00:00
# 297538       50498.0        Strong Wind  03-APR-11 09:00:00
# 297539       50498.0        Strong Wind  03-APR-11 09:00:00
# 296632       50373.0               Hail  04-JUN-11 16:43:00
# 296635       50373.0               Hail  04-JUN-11 17:48:00
# 296634       50373.0               Hail  04-JUN-11 17:46:00
# 296637       50373.0               Hail  04-JUN-11 17:52:00
# 296646       50373.0               Hail  04-JUN-11 18:35:00
# 296647       50373.0               Hail  04-JUN-11 18:37:00
# 321608       50373.0  Thunderstorm Wind  04-JUN-11 16:25:00
# 321666       50373.0  Thunderstorm Wind  04-JUN-11 17:30:00
# ...              ...                ...                 ...
# 5625882    2071232.0          Dense Fog  09-DEC-97 05:00:00
# 5625883    2071232.0          Dense Fog  09-DEC-97 05:00:00
# 5626133    2071239.0         Heavy Snow  30-DEC-97 14:00:00
# 5599335    2063447.0  Thunderstorm Wind  08-SEP-97 16:28:00
# 5626135    2071239.0         Heavy Snow  30-DEC-97 14:00:00
# 5625887    2071233.0          Dense Fog  15-DEC-97 06:00:00
# 5625888    2071233.0          Dense Fog  15-DEC-97 06:00:00
# 5625889    2071233.0          Dense Fog  15-DEC-97 06:00:00
# 5625890    2071233.0          Dense Fog  15-DEC-97 06:00:00
# 5599435    2063447.0  Thunderstorm Wind  19-SEP-97 19:50:00
# 5599436    2063447.0          High Wind  29-SEP-97 13:52:00
# 5599334    2063447.0  Thunderstorm Wind  02-SEP-97 16:30:00
# 5625888               0                0             NaN          NaN
# 5625889               0                0             NaN          NaN
# 5625890               0                0             NaN          NaN
# 5599435               0                0            1.5K          NaN
# 5599436               0                0             NaN          NaN
# 5599334               0                0            1.5K          NaN
# 5626132               0                0             NaN          NaN
# 5621223               0                0             NaN          NaN
# 5621224               0                0             NaN          NaN
# 5621225               0                0             NaN          NaN
# 5621226               0                0             NaN          NaN
# 5621227               0                0             NaN          NaN
# 5621228               0                0             NaN          NaN
# 5621229               0                0             NaN          NaN
# 5625914               0                0             NaN          NaN
# 5625915               0                0             NaN          NaN
# 5625913               0                0             NaN          NaN
# 5621497               0                0             NaN          NaN
# 5625911               0                0             NaN          NaN
# 5625912               0                0             NaN          NaN
# 5626131               0                0             NaN          NaN
# 5626134               0                0             NaN          NaN
# 5610200               0                0              5K          NaN
# 5626136               0                0             NaN          NaN
#
#           MAGNITUDE
# EVENT_ID
# 307217          NaN
# 324730         0.88
# 324732        65.00
# 324733        60.00
# 324735        60.00
# 324736        60.00
# 292417          NaN
# 296542          NaN
# 316044          NaN
# 316037          NaN
# 316052          NaN
# 316055          NaN
# 299173         1.00
# 299176         0.88
# 299233         1.00
# 299240         1.00
# 297533        39.00
# 297534        39.00
# 297535        39.00
# 297536        40.00
# 297538        40.00
# 297539        40.00
# 296632         1.00
# 296635         0.88
# 296634         1.00
# 296637         1.00
# 296646         1.00
# 296647         0.75
# 321608        55.00
# 321666        55.00
# ...             ...
# 5625882         NaN
# 5625883         NaN
# 5626133         NaN
# 5599335         NaN
# 5626135         NaN
# 5625887         NaN
# 5625888         NaN
# 5625889         NaN
# 5625890         NaN
# 5599435         NaN
# 5599436       45.00
# 5599334         NaN
# 5626132         NaN
# 5621223         NaN
# 5621224         NaN
# 5621225         NaN
# 5621226         NaN
# 5621227         NaN
# 5621228         NaN
# 5621229         NaN
# 5625914         NaN
# 5625915         NaN
# 5625913         NaN
# 5621497        1.00
# 5625911         NaN
# 5625912         NaN
# 5626131         NaN
# 5626134         NaN
# 5610200       60.00
# 5626136         NaN
#
# [21494 rows x 11 columns]

# %%
#Comprobamos si hay eventos sin episodio
details_df.EPISODE_ID.isnull().values.any()
# Out:
# True

# %%
#Eliminamos aquellos eventos que no tengan asociado un episodio (tormenta)
details_df = details_df[details_df.EPISODE_ID.notnull()]
details_df.EPISODE_ID.isnull().values.any()
# Out:
# False

# %%
#Comprobamos si hay algun evento sin tipo de evento
details_df.EVENT_TYPE.isnull().values.any()
# Out:
# False

# %%
#Convertimos los episodios a tipo entero
details_df.loc[:, 'EPISODE_ID'] = details_df['EPISODE_ID'].apply(lambda x: int(x))

# %%
#Damos formato a las fechas
details_df.loc[:, 'BEGIN_DATE_TIME'] = pd.to_datetime(details_df['BEGIN_DATE_TIME'])
details_df.loc[:, 'END_DATE_TIME'] = pd.to_datetime(details_df['END_DATE_TIME'])

# %%
details_df[['INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DAMAGE_CROPS',
            'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS']] = details_df[['INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT', 'DAMAGE_CROPS',
            'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS']].fillna('0')

# %%
#Convertismos las perdidas de propiedades y de cultivos en un numero entero ($)
def procesar_perdidas(x):
    if x == '0' or x == 0:
        return int(x)
    else:
        if x[-1] == 'K':
            mult = 1e3
        elif x[-1] == 'M':
            mult = 1e6
        else:
            mult = 1
        
        return int(float(x[:-1]) * mult)

# %%
details_df['DAMAGE_PROPERTY'] = details_df['DAMAGE_PROPERTY'].apply(procesar_perdidas)
# Out:
# /home/pablo/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
details_df['DAMAGE_CROPS'] = details_df['DAMAGE_CROPS'].apply(procesar_perdidas)
# Out:
# /home/pablo/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
details_df['DAMAGE_PROPERTY'].unique()
# Out:
# array([        0,     10000,      1000,     15000,     75000,      2000,
#             5000,     20000,     25000,      8000,     17000,      9000,
#             3000,      1500,       250,      4000,       500,      7000,
#             6000,      1250,     12000,     21000,     18000,      7500,
#              200,     50000,     90000,     30000,    100000,    500000,
#            70000,   1000000,    147000,   1500000,    105000,     55000,
#            45000,     35000,     43000,     20500,     80000,     40000,
#           206000,    300000,    200000,    400000,     65000,     16000,
#           150000,    110000,    250000,    350000,       800,     28000,
#            60000,    750000,       100,    975000,      3500,       750,
#           125000,     12500,   3500000,    120000,      9500,     13000,
#             2500,     36000,      2250,     14000,    420000,   3000000,
#          2000000,   6000000,  15000000,   8000000,   5000000,     85000,
#              300,  10000000,    450000,  35000000,  25000000,     35200,
#          1300000,    175000,   1650000,   1100000,     38000,     31000,
#         19000000,   2500000,   1200000,    465000,     11000,      5500,
#             8500,   6500000,    425000,     13500,    936000,   1150000,
#            44000,     32000,  11000000,    180000,    600000,   4000000,
#            19000,     49000,    265000,   1800000,     68000,      2600,
#         12000000,    260000,   1250000,    160000,       600,    226000,
#         23000000,  29000000,  20000000,  80000000,  50000000, 100000000,
#         45000000, 150000000,  30000000,  90000000,     53000,   2900000,
#          2700000,    856000,   8100000,    684000,   3300000,   5800000,
#               10,    115000,     25500,    280000,    240000,       700,
#           825000,    190000,  11600000,     12900,  65000000,    275000,
#            48000,  55000000,      1750,       150,     63000,     83000,
#            62000,     33000,     84000,     34000,    800000,  40000000,
#          5100000,   7000000,  18000000,   4500000,  10600000,  31000000,
#             1300,       400])

# %%
details_df.DAMAGE_CROPS.unique()
# Out:
# array([        0,     50000,     30000,     20000,     10000,       250,
#             1000,       500,      3000,      5000,      2000,       100,
#              200,   2000000,      6000,     25000,       300,       750,
#             8000,      7000,      2500,     12000,      4000,    300000,
#           200000,     40000,   3030000,    620000,    100000,   1000000,
#             1500,     75000,    400000,    250000,     15000,  10000000,
#           500000,  60000000,  30000000, 100000000,  45000000, 150000000,
#         50000000,  90000000,  15000000,   5000000,   4000000,  70000000,
#          8000000,   7000000,   3000000,   6000000])
