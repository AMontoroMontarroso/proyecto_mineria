# %%
import pandas as pd
from pandas import DataFrame
''' En esta parte preprocesamos los datos de los accidentes. En primer lugar
    Vamos a convertir las tablas de la fecha en fechas reales. Despues se van
    a detectar posibles valores nulos que se hayan podido causar
'''

accidents = pd.read_csv('../Data/Seleccion/accidents.csv')

# %%
# transformamos los datos del año, mes y día a entero (antes estaba en float)
accidents.YEAR = accidents.YEAR.map(lambda x: int(x))
accidents.DAY = accidents.DAY.map(lambda x: int(x))
accidents.MONTH = accidents.MONTH.map(lambda x: int(x))

# %%
# definimos la funcion que nos va a transformar a fecha

def to_date(accidents):
    result = []
    for i in range(len(accidents['YEAR'])):
        res = "{}/{}/{}".format(accidents['YEAR'][i], accidents['MONTH'][i], accidents['DAY'][i],)
        result.append(pd.to_datetime(res, format="%Y/%m/%d"))
    return result

# %%
'''
Pasamos las fechas a datetime de pandas y luego lo insertamos en una nueva columna
Una vez hecho eso, se eliminan las columnas que no hagan falta
'''

res = to_date(accidents)

accidents['DATE'] = DataFrame(res)

accidents = accidents.drop(['HOUR', 'MINUTE', 'DAY', 'HOUR', 'MONTH', 'YEAR'], axis=1)
accidents
# Out:
#        Unnamed: 0  DRUNK_DR  FATALS   LATITUDE   LONGITUD  STATE       DATE
# 0           12927       0.0     1.0  40.306125 -85.648019   18.0 2001-01-02
# 1           12928       0.0     1.0  40.091233 -85.620006   18.0 2001-01-02
# 2           12929       0.0     1.0  39.833939 -85.972061   18.0 2001-01-02
# 3           12930       0.0     1.0  41.493975 -85.921294   18.0 2001-01-03
# 4           12931       0.0     1.0  39.989464 -86.202700   18.0 2001-01-03
# 5           12932       0.0     1.0  39.731422 -86.504850   18.0 2001-01-03
# 6           12933       0.0     1.0  41.679753 -86.699894   18.0 2001-01-03
# 7           12934       0.0     1.0  40.004408 -85.299808   18.0 2001-01-04
# 8           12935       0.0     1.0  38.505711 -87.256103   18.0 2001-01-04
# 9           12936       0.0     1.0  39.486650 -85.479392   18.0 2001-01-04
# 10          12937       0.0     1.0  40.150967 -86.905006   18.0 2001-01-05
# 11          12938       1.0     1.0  37.994014 -87.557444   18.0 2001-01-05
# 12          12939       0.0     1.0  41.077239 -85.138786   18.0 2001-01-06
# 13          12940       1.0     1.0  41.449344 -87.336500   18.0 2001-01-06
# 14          12941       0.0     1.0  39.713378 -86.139292   18.0 2001-01-06
# 15          12942       2.0     1.0  39.450681 -87.150025   18.0 2001-01-07
# 16          12943       1.0     1.0  39.863717 -86.157031   18.0 2001-01-07
# 17          12944       0.0     1.0  38.303172 -85.753292   18.0 2001-01-08
# 18          12945       0.0     1.0  40.133269 -85.911103   18.0 2001-01-08
# 19          12946       0.0     1.0  38.507517 -86.443100   18.0 2001-01-08
# 20          12947       0.0     1.0  39.771047 -86.064058   18.0 2001-01-09
# 21          12948       0.0     1.0  38.655444 -87.127019   18.0 2001-01-10
# 22          12949       0.0     1.0  38.239961 -86.218306   18.0 2001-01-11
# 23          12950       1.0     1.0  41.130308 -85.895392   18.0 2001-01-11
# 24          12951       0.0     2.0  38.035519 -86.086022   18.0 2001-01-12
# 25          12952       1.0     1.0  40.615736 -85.938931   18.0 2001-01-12
# 26          12953       0.0     1.0  40.748969 -86.065442   18.0 2001-01-14
# 27          12954       0.0     3.0  40.499331 -86.877058   18.0 2001-01-14
# 28          12955       0.0     1.0  40.131264 -86.128225   18.0 2001-01-15
# 29          12956       0.0     1.0  41.460442 -87.047086   18.0 2001-01-18
# ...           ...       ...     ...        ...        ...    ...        ...
# 11224       11904       0.0     1.0  41.668414 -86.283236   18.0 2015-12-25
# 11225       11905       0.0     1.0  40.887444 -86.147686   18.0 2015-12-20
# 11226       11906       0.0     1.0  41.563233 -87.281778   18.0 2015-11-11
# 11227       11907       0.0     1.0  41.529569 -85.055817   18.0 2015-12-28
# 11228       11908       0.0     1.0  41.550211 -87.182536   18.0 2015-12-29
# 11229       11909       0.0     1.0  39.719511 -86.024758   18.0 2015-12-06
# 11230       11910       1.0     1.0  39.816714 -86.233400   18.0 2015-12-25
# 11231       11911       0.0     1.0  39.709550 -86.063553   18.0 2015-12-24
# 11232       11912       0.0     1.0  39.949661 -86.312619   18.0 2015-12-30
# 11233       11913       1.0     1.0  40.383442 -86.953608   18.0 2015-12-02
# 11234       11914       1.0     1.0  40.806075 -85.377389   18.0 2015-11-14
# 11235       11915       1.0     1.0  41.569794 -87.414567   18.0 2015-12-23
# 11236       11916       0.0     1.0  39.959356 -86.704900   18.0 2015-12-24
# 11237       11917       0.0     3.0  39.698647 -86.148703   18.0 2015-12-23
# 11238       11918       0.0     1.0  41.656694 -87.461367   18.0 2015-12-19
# 11239       11919       0.0     1.0  37.973614 -87.552550   18.0 2015-11-24
# 11240       11920       0.0     1.0  40.219539 -85.789397   18.0 2015-12-31
# 11241       11921       1.0     2.0  39.864328 -86.046031   18.0 2015-12-13
# 11242       11922       0.0     1.0  39.711947 -86.270303   18.0 2015-12-19
# 11243       11923       0.0     1.0  39.841783 -86.211753   18.0 2015-05-29
# 11244       11924       1.0     4.0  39.509156 -86.319392   18.0 2015-12-30
# 11245       11925       0.0     1.0  39.575583 -86.857956   18.0 2015-12-03
# 11246       11926       0.0     2.0  39.829161 -86.240278   18.0 2015-12-25
# 11247       11927       0.0     1.0  39.770028 -85.443000   18.0 2015-12-22
# 11248       11928       0.0     1.0  38.320783 -85.743469   18.0 2015-10-22
# 11249       11929       0.0     1.0  39.772056 -86.098608   18.0 2015-12-09
# 11250       11930       1.0     1.0  38.359297 -87.567414   18.0 2015-01-11
# 11251       11931       0.0     1.0  40.043186 -86.070811   18.0 2015-12-27
# 11252       11932       0.0     1.0  41.237086 -86.733239   18.0 2015-06-14
# 11253       11933       0.0     1.0  41.463144 -87.036667   18.0 2015-10-30
#
# [11254 rows x 7 columns]

# %%
# Vemos si algun valor es nulo. Como ninguno es nulo, en principio es correcto

accidents.isnull().any()
# Out:
# Unnamed: 0    False
# DRUNK_DR      False
# FATALS        False
# LATITUDE      False
# LONGITUD      False
# STATE         False
# DATE          False
# dtype: bool

# %%
# Dibujamos los resultados, no vaya a ser que esto esté mal
import matplotlib.pyplot as plt

plt.scatter(accidents['LATITUDE'], accidents['LONGITUD'])
plt.show()

# %%
# Hay unas fechas mal metidas, así que vamos a eliminarlas

accidents = accidents[accidents["LATITUDE"] > 20]
accidents = accidents[accidents["LATITUDE"] < 40]

plt.scatter(accidents['LATITUDE'], accidents['LONGITUD'])
plt.show()

# Ahora funciona

# %%
accidents.to_csv("../Data/Preproceso/accidents.csv")
